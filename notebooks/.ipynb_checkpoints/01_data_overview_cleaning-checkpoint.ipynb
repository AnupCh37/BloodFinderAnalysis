# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  
import sklearn as skl
import scipy
import statsmodels.api as sm

# %%
df=pd.read_csv('../data/blooddonerdataset.csv')

# %%
df.head()
# Out:
#               name   donor_id blood_group location_name  latitude  longitude  \
# 0      Sunil Magar  DNR000001          A-        Thamel   27.7156    85.3123
# 1    Deepak Tamang  DNR000002         AB+     Koteshwor   27.6789    85.3497
# 2     Deepa Subedi  DNR000003          O-        Boudha   27.7215    85.3616
# 3  Deepak Shrestha  DNR000004          O+        Thamel   27.7156    85.3123
# 4   Utsav Shrestha  DNR000005         AB+     Baneshwor   27.6895    85.3420
#
#                 email  contact_number  age        donor_status  ...  \
# 0  donor1@example.com      9708644683   35  Temporary Deferred  ...
# 1  donor2@example.com      9813473886   46              Active  ...
# 2  donor3@example.com      9826572966   34              Active  ...
# 3  donor4@example.com      9822540002   32  Temporary Deferred  ...
# 4  donor5@example.com      9814324213   58              Active  ...
#
#        verified_by registration_date donation_count  \
# 0              NaN        2025-06-14              3
# 1              NaN        2025-01-17              0
# 2              NaN        2025-07-01              3
# 3   Hospital Admin        2023-11-23             14
# 4  Nepal Red Cross        2025-08-17             21
#
#   donation_frequency_per_year  days_since_last_donation  eligibility_status  \
# 0                        0.18                     588.0                  No
# 1                        0.00                       NaN                 Yes
# 2                        0.19                     417.0                  No
# 3                        1.00                     680.0                 Yes
# 4                        0.53                     362.0                 Yes
#
#   eligibility_reason distance_to_center_km response_time_minutes record_status
# 0     Recent Illness                  1.06                    33        Active
# 1           Eligible                  6.45                    49        Active
# 2     Recent Illness                 15.01                   168      Archived
# 3           Eligible                  6.72                    78        Active
# 4           Eligible                 14.59                   112      Archived
#
# [5 rows x 34 columns]

# %%
df["blood_group"]
#working with the specific column in dataframe
# Out:
# 0        A-
# 1       AB+
# 2        O-
# 3        O+
# 4       AB+
#        ...
# 9995     B+
# 9996    AB+
# 9997     A-
# 9998     B-
# 9999     O+
# Name: blood_group, Length: 10000, dtype: object

# %%
df["blood_group"].max()
# not meaning full but return lexicographically largest value
# Out:
# 'O-'

# %%
bloodgrp=df["blood_group"]
bloodgrp
#creating the series from scratch
# Out:
# 0        A-
# 1       AB+
# 2        O-
# 3        O+
# 4       AB+
#        ...
# 9995     B+
# 9996    AB+
# 9997     A-
# 9998     B-
# 9999     O+
# Name: blood_group, Length: 10000, dtype: object

# %%
df.describe()
#give statistical summary of your dataset
# Out:
#                  name   donor_id blood_group location_name      latitude  \
# count           10000      10000       10000         10000  10000.000000
# unique           2146      10000           8             7           NaN
# top     Sangita Rijal  DNR009984          A+       Kalanki           NaN
# freq               14          1        1292          1489           NaN
# mean              NaN        NaN         NaN           NaN     27.691261
# std               NaN        NaN         NaN           NaN      0.019474
# min               NaN        NaN         NaN           NaN     27.667300
# 25%               NaN        NaN         NaN           NaN     27.671000
# 50%               NaN        NaN         NaN           NaN     27.689500
# 75%               NaN        NaN         NaN           NaN     27.715600
# max               NaN        NaN         NaN           NaN     27.721500
#
#            longitude                  email  contact_number           age  \
# count   10000.000000                  10000    1.000000e+04  10000.000000
# unique           NaN                  10000             NaN           NaN
# top              NaN  donor9984@example.com             NaN           NaN
# freq             NaN                      1             NaN           NaN
# mean       85.341979                    NaN    9.786477e+09     38.996700
# std         0.043836                    NaN    5.734177e+07     12.383183
# min        85.281900                    NaN    9.700000e+09     18.000000
# 25%        85.312300                    NaN    9.720227e+09     28.000000
# 50%        85.342000                    NaN    9.810422e+09     39.000000
# 75%        85.361600                    NaN    9.840108e+09     50.000000
# max        85.429800                    NaN    9.859991e+09     60.000000
#
#        donor_status  ...      verified_by registration_date donation_count  \
# count         10000  ...             4973             10000   10000.000000
# unique            3  ...                3              1469            NaN
# top        Inactive  ...  Nepal Red Cross        2022-12-12            NaN
# freq           3444  ...             1670                19            NaN
# mean            NaN  ...              NaN               NaN      12.545700
# std             NaN  ...              NaN               NaN       7.490923
# min             NaN  ...              NaN               NaN       0.000000
# 25%             NaN  ...              NaN               NaN       6.000000
# 50%             NaN  ...              NaN               NaN      13.000000
# 75%             NaN  ...              NaN               NaN      19.000000
# max             NaN  ...              NaN               NaN      25.000000
#
#        donation_frequency_per_year  days_since_last_donation  \
# count                 10000.000000               9612.000000
# unique                         NaN                       NaN
# top                            NaN                       NaN
# freq                           NaN                       NaN
# mean                      1.541424                375.514149
# std                       3.232697                199.638492
# min                       0.000000                 30.000000
# 25%                       0.290000                199.000000
# 50%                       0.590000                379.500000
# 75%                       1.220000                547.000000
# max                      25.000000                720.000000
#
#         eligibility_status eligibility_reason distance_to_center_km  \
# count                10000              10000          10000.000000
# unique                   2                  4                   NaN
# top                    Yes           Eligible                   NaN
# freq                  6520               6520                   NaN
# mean                   NaN                NaN              9.144172
# std                    NaN                NaN              5.054156
# min                    NaN                NaN              0.500000
# 25%                    NaN                NaN              4.670000
# 50%                    NaN                NaN              9.150000
# 75%                    NaN                NaN             13.482500
# max                    NaN                NaN             18.000000
#
#        response_time_minutes record_status
# count           10000.000000         10000
# unique                   NaN             2
# top                      NaN        Active
# freq                     NaN          5000
# mean               94.852200           NaN
# std                49.439433           NaN
# min                10.000000           NaN
# 25%                52.000000           NaN
# 50%                94.000000           NaN
# 75%               137.000000           NaN
# max               180.000000           NaN
#
# [11 rows x 34 columns]
